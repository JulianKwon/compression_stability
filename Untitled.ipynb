# %%
from data import HouseholdElectricDataset
import pandas as pd
import os

# %%
window_size = 24*7
prediction_length = 24*7 

dilation = 60 # hourly data
test_size=0.2
data_path = '/workspace/TSDataset/'




dataset = HouseholdElectricDataset('household_power_consumption.csv', data_path, window_size, prediction_length)
# Out:
# /workspace/TSDataset/household_power_consumption.csv

# %%
train_loader = dataset.make_dataloader(type='train', batch_size=500)

# %%
plt.plot(dataset.data[:190,0])

# %%
for X, y in train_loader:
    print(X.shape, y.shape)
    break
# Out:
# torch.Size([500, 1344]) torch.Size([500, 168])

# %%
X = X.reshape(X.shape[0], 8, int(X.shape[1] / 8))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
sns.set_palette('muted')

# %%
import numpy as np

# %%
x_ind = np.arange(0, 168, 1)
plt.plot(x_ind,X[0,0,:])
x_ind = np.arange(168, 168*2, 1)
plt.plot(x_ind,y[0])

# %%
plt.plot(dataset.X_train[0,1,:])
