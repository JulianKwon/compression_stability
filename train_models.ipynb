# %%
# !python train_resnet.py -c=6 -e=100 -m=0 -l=0.001 -d=imagenet
# Out:
# Namespace(cuda_num=6, dataset='imagenet', epochs=100, lr=0.001, mode=0, num_class=10)
# Using augmented IMAGENET.
# /workspace/Julian/compression_stability/training/iteration.py:122: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred = F.softmax(pred)
#  Epoch: [0][0/130]	Time 1.612 (1.612)	Data 1.363 (1.363)	Loss 0.7408 (0.7408)
#  Epoch: [0][100/130]	Time 0.260 (0.245)	Data 0.107 (0.091)	Loss 0.5731 (0.7598)
# (13000, 10) (13000,) (13000,)
# /workspace/Julian/compression_stability/training/iteration.py:122: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred = F.softmax(pred)
#  Epoch: [0][0/5]	Time 1.795 (1.795)	Data 1.715 (1.715)	Loss 0.6945 (0.6945)
# (500, 10) (500,) (500,)
# ...

# %%
# !python train_resnet.py -c=6 -e=100 -m=2 -l=0.001 -d=imagenet
# Out:
# Namespace(cuda_num=6, dataset='imagenet', epochs=100, lr=0.001, mode=2, num_class=10, resnet_mode='resnet18')
# Using augmented IMAGENET.
# /workspace/Julian/compression_stability/training/iteration.py:122: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred = F.softmax(pred)
#  Epoch: [0][0/130]	Time 1.769 (1.769)	Data 1.711 (1.711)	Loss 0.5603 (0.5603)
#  Epoch: [0][100/130]	Time 0.852 (0.245)	Data 0.812 (0.204)	Loss 0.6539 (0.7135)
# (13000, 10) (13000,) (13000,)
# /workspace/Julian/compression_stability/training/iteration.py:122: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred = F.softmax(pred)
#  Epoch: [0][0/5]	Time 1.456 (1.456)	Data 1.408 (1.408)	Loss 0.7836 (0.7836)
# (500, 10) (500,) (500,)
# Using augmented IMAGENET.
# ...

# %%
state = torch.load('./runs/l0LeNet_sparsecoding/sparsity10/checkpoint_valid.pth.tar')

# %%
import torchvision.models as models

# %%
model = getattr(models, 'resnet18')(pretrained=True)
input_feature_fc_layer = model.fc.in_features
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# ...

# %%
input_feature_fc_layer
# Out:
# 512

# %%
model.fc.out_features
# Out:
# 1000

# %%
# !python train_resnet.py -c=6 -e=100 -m=1 -l=0.001 -d=imagenet -n=10 -p=True -r=resnet152
# Out:
# Namespace(cuda_num=6, dataset='imagenet', epochs=100, lr=0.001, mode=1, num_class=10, pre_trained=True, resnet_mode='resnet152')
# Using augmented IMAGENET.
# Traceback (most recent call last):
#   File "train_resnet.py", line 179, in <module>
#     classes=args.num_class)
#   File "train_resnet.py", line 73, in sparse_coding
#     model = model_loader(model_name=name, pretrain=preTrained, num_class=num_classes)
#   File "/workspace/Julian/compression_stability/models/model_loader.py", line 6, in model_loader
#     'mobilenet_v2', 'mobilenet_v3_large', 'mnasnet'], "no model in 'models' module."
# AssertionError: no model in 'models' module.

# %%
# !python train_resnet.py
# Out:
# usage: train_resnet.py [-h] [-c CUDA_NUM] [-e EPOCHS] [-m MODE]
#                        [-r RESNET_MODE] [-l LR] [-d DATASET] [-n NUM_CLASS]
#                        [-p PRE_TRAINED]
#
# PyTorch ResNet18 Training
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -c CUDA_NUM, --cuda-num CUDA_NUM
#                         cuda gpu number
#   -e EPOCHS, --epochs EPOCHS
#                         number of total epochs to run
#   -m MODE, --mode MODE  training mode. (0: pretrain, 1: sparse coding)
#   -r RESNET_MODE, --resnet-mode RESNET_MODE
#                         resnet mode. resnet18~resnet152
#   -l LR, --lr LR        learning rate of optimizer
#   -d DATASET, --dataset DATASET
#                         learning rate of optimizer
#   -n NUM_CLASS, --num-class NUM_CLASS
#                         number of classes
#   -p PRE_TRAINED, --pre-trained PRE_TRAINED
#                         model pretrained flag
